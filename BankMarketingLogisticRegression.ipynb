# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.read_csv("F:/Pandas/bank+marketing/bank-additional/bank-additional/bank-additional.csv", sep=";")
df1=df

# %%
df.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
# ...

# %%
df.shape
# Out:
# (4119, 21)

# %%
df.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
len(df)
# Out:
# 4119

# %%
df.head().T
# Out:
#                           0            1            2            3  \
# age                      30           39           25           38
# job             blue-collar     services     services     services
# marital             married       single      married      married
# education          basic.9y  high.school  high.school     basic.9y
# default                  no           no           no           no
# housing                 yes           no          yes      unknown
# loan                     no           no           no      unknown
# contact            cellular    telephone    telephone    telephone
# month                   may          may          jun          jun
# day_of_week             fri          fri          wed          fri
# duration                487          346          227           17
# campaign                  2            4            1            3
# pdays                   999          999          999          999
# ...

# %%
needed_columns = ['age','job','marital','education',
'balance',
'housing',
'contact',
'day',
'month',
'duration',
'campaign',
'pdays',
'previous',
'poutcome']

# %%
needed_columns
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'balance',
#  'housing',
#  'contact',
#  'day',
#  'month',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome']

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df.education.unique()
# Out:
# array(['basic.9y', 'high.school', 'university.degree',
#        'professional.course', 'basic.6y', 'basic.4y', 'unknown',
#        'illiterate'], dtype=object)

# %%
mode_education = df['education'].mode()
mode_education
# Out:
# 0    university.degree
# Name: education, dtype: object

# %%
df.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4119.000000  4119.000000  4119.000000  4119.000000
# mean     40.113620   256.788055     2.537266   960.422190     0.190337
# std      10.313362   254.703736     2.568159   191.922786     0.541788
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.000000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   4119.000000     4119.000000    4119.000000  4119.000000  4119.000000
# mean       0.084972       93.579704     -40.499102     3.621356  5166.481695
# std        1.563114        0.579349       4.594578     1.733591    73.667904
# ...

# %%
numerical = df.select_dtypes(include=['number'])
numerical
# Out:
#       age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0      30       487         2    999         0          -1.8          92.893
# 1      39       346         4    999         0           1.1          93.994
# 2      25       227         1    999         0           1.4          94.465
# 3      38        17         3    999         0           1.4          94.465
# 4      47        58         1    999         0          -0.1          93.200
# ...   ...       ...       ...    ...       ...           ...             ...
# 4114   30        53         1    999         0           1.4          93.918
# 4115   39       219         1    999         0           1.4          93.918
# 4116   27        64         2    999         1          -1.8          92.893
# 4117   58       528         1    999         0           1.4          93.444
# 4118   34       175         1    999         0          -0.1          93.200
#
#       cons.conf.idx  euribor3m  nr.employed
# ...

# %%
correlation_matrix = numerical.corr()

# %%
correlation_matrix
# Out:
#                      age  duration  campaign     pdays  previous  \
# age             1.000000  0.041299 -0.014169 -0.043425  0.050931
# duration        0.041299  1.000000 -0.085348 -0.046998  0.025724
# campaign       -0.014169 -0.085348  1.000000  0.058742 -0.091490
# pdays          -0.043425 -0.046998  0.058742  1.000000 -0.587941
# previous        0.050931  0.025724 -0.091490 -0.587941  1.000000
# emp.var.rate   -0.019192 -0.028848  0.176079  0.270684 -0.415238
# cons.price.idx -0.000482  0.016672  0.145021  0.058472 -0.164922
# cons.conf.idx   0.098135 -0.034745  0.007882 -0.092090 -0.051420
# euribor3m      -0.015033 -0.032329  0.159435  0.301478 -0.458851
# nr.employed    -0.041936 -0.044218  0.161037  0.381983 -0.514853
#
#                 emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# age                -0.019192       -0.000482       0.098135  -0.015033
# duration           -0.028848        0.016672      -0.034745  -0.032329
# ...

# %%
sorted_correlation = correlation_matrix.unstack().sort_values(ascending = True)
sorted_correlation[sorted_correlation !=1].head()
# Out:
# previous     pdays         -0.587941
# pdays        previous      -0.587941
# previous     nr.employed   -0.514853
# nr.employed  previous      -0.514853
# euribor3m    previous      -0.458851
# dtype: float64

# %%
df['pdays'].corr(df['previous'])
# Out:
# -0.5879411425842276

# %%
df.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
df.y= (df.y == 'yes').astype(int)

# %%
df.y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: y, dtype: int32

# %%
target=df.y
target.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: y, dtype: int32

# %%
from sklearn.model_selection import train_test_split
df_full_train, df_test= train_test_split(df, test_size=0.2, random_state=42)
df_train, df_val = train_test_split(df_full_train, test_size=0.33, random_state =42)
y_train = df_train.y
y_val = df_val.y

# %%
df_full_train.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
del df['y']

# %%
df1.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  duration  campaign  pdays  previous  \
# 0   cellular   may         fri       487         2    999         0
# 1  telephone   may         fri       346         4    999         0
# 2  telephone   jun         wed       227         1    999         0
# 3  telephone   jun         fri        17         3    999         0
# 4   cellular   nov         mon        58         1    999         0
#
#       poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# ...

# %%
del df_train['y']
del df_val['y']

# %%
df.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# dtype: object

# %%
df.head(10)
# Out:
#    age           job   marital            education  default  housing  \
# 0   30   blue-collar   married             basic.9y       no      yes
# 1   39      services    single          high.school       no       no
# 2   25      services   married          high.school       no      yes
# 3   38      services   married             basic.9y       no  unknown
# 4   47        admin.   married    university.degree       no      yes
# 5   32      services    single    university.degree       no       no
# 6   32        admin.    single    university.degree       no      yes
# 7   41  entrepreneur   married    university.degree  unknown      yes
# 8   31      services  divorced  professional.course       no       no
# 9   35   blue-collar   married             basic.9y  unknown       no
#
#       loan    contact month day_of_week  duration  campaign  pdays  previous  \
# 0       no   cellular   may         fri       487         2    999         0
# ...

# %%
df['job'].nunique()
# Out:
# 12

# %%
df['marital'].nunique()
# Out:
# 4

# %%
df['housing'].nunique()
df['contact'].nunique()
# Out:
# 2

# %%
df['day_of_week'].nunique()
# Out:
# 5

# %%
df['duration'].nunique()
# Out:
# 828

# %%
df['poutcome'].nunique()
# Out:
# 3

# %%
categorical = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome']

# %%
numerical = ['age', 'duration', 'campaign', 'pdays', 'previous']

# %%
from sklearn.metrics import mutual_info_score
def calculate_mi(series):
    return mutual_info_score(series, df_full_train.y)

df_mi = df_full_train[categorical].apply(calculate_mi)
df_mi = df_mi.sort_values(ascending=False).to_frame(name='MI')

df_mi
# Out:
#                    MI
# poutcome     0.033915
# month        0.021257
# contact      0.012044
# job          0.009087
# education    0.003149
# default      0.002785
# marital      0.001605
# housing      0.000544
# loan         0.000493
# day_of_week  0.000131

# %%
df_full_train.y
# Out:
# 324     0
# 2350    0
# 1391    0
# 468     0
# 561     0
#        ..
# 3444    0
# 466     0
# 3092    0
# 3772    0
# 860     0
# Name: y, Length: 3295, dtype: int32

# %%
df_train['y']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'y'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[388], line 1
# ----> 1 df_train['y']
#
# ...

# %%
df_train_encoded = pd.get_dummies(df_train, columns=categorical, drop_first=True)

# %%
df_val_encoded = pd.get_dummies(df_val, columns=categorical, drop_first=True)

# %%
df_val_encoded = df_val_encoded.reindex(columns=df_train_encoded.columns, fill_value=0)

# %%
df_train_encoded.head()
# Out:
#       age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 560    41       206         1    999         0           1.4          93.444
# 2581   33       165         1    999         1          -1.8          92.893
# 2641   24       453         1    999         0           1.4          94.465
# 2876   35       112         1    999         0          -0.1          93.200
# 2759   28       278         2    999         0           1.4          93.918
#
#       cons.conf.idx  euribor3m  nr.employed  ...  month_may  month_nov  \
# 560           -36.1      4.965       5228.1  ...      False      False
# 2581          -46.2      1.266       5099.1  ...       True      False
# 2641          -41.8      4.962       5228.1  ...      False      False
# 2876          -42.0      4.120       5195.8  ...      False       True
# 2759          -42.7      4.957       5228.1  ...      False      False
#
# ...

# %%
df_train_encoded = df_train_encoded.astype(int)
df_val_encoded = df_val_encoded.astype(int)

# %%
df_train_encoded
# Out:
#       age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 560    41       206         1    999         0             1              93
# 2581   33       165         1    999         1            -1              92
# 2641   24       453         1    999         0             1              94
# 2876   35       112         1    999         0             0              93
# 2759   28       278         2    999         0             1              93
# ...   ...       ...       ...    ...       ...           ...             ...
# 2547   34       369         2    999         1            -1              92
# 1088   39       261         1      3         1            -3              92
# 939    34       423         1    999         0             1              94
# 1565   38       195         2    999         0            -2              92
# 1162   56       177         5    999         0             1              93
#
# ...

# %%
print(set(df_train_encoded.columns) - set(df_val_encoded.columns))
print(set(df_val_encoded.columns) - set(df_train_encoded.columns))
# Out:
# set()
# set()

# %%
print((df_train_encoded.columns == df_val_encoded.columns).all())
# Out:
# True

# %%
df_test_encoded = pd.get_dummies(df_test, columns=categorical, drop_first=True)

# %%
df_test_encoded = df_test_encoded.reindex(columns=df_train_encoded.columns, fill_value=0)

# %%
df_test_encoded = df_test_encoded.astype(int)

# %%
df_test_encoded.head().T
# Out:
#                                889   2669  2707  2258  2514
# age                              48    35    56    29    62
# duration                        544    98   212   247   163
# campaign                          1     1     1     2     2
# pdays                           999   999   999   999   999
# previous                          0     0     1     0     0
# emp.var.rate                     -1     1     0    -2    -1
# cons.price.idx                   94    94    93    92    92
# cons.conf.idx                   -38   -41   -42   -40   -50
# euribor3m                         0     4     4     1     1
# nr.employed                    4991  5228  5195  5076  5099
# job_blue-collar                   0     0     0     0     0
# job_entrepreneur                  0     0     0     0     0
# job_housemaid                     0     0     1     0     0
# job_management                    0     0     0     0     0
# job_retired                       0     0     0     0     0
# ...

# %%
from sklearn.linear_model import LogisticRegression
y_train_encoded = df_full_train.y

# %%
model = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)

# %%
print(set(df_test_encoded.columns) - set(df_val_encoded.columns))
# Out:
# set()

# %%
df_train_encoded.shape
# Out:
# (2207, 52)

# %%
df_test_encoded.shape
# Out:
# (824, 52)

# %%
y_train_encoded.shape
# Out:
# (3295,)

# %%
from sklearn.model_selection import train_test_split

df_train, df_val, y_train, y_val = train_test_split(df1, target, test_size=0.2, random_state=42)
print(df_train_encoded.shape[0])
# Out:
# 2207

# %%
df_train = df_train.fillna('missing')

# %%
df_train_encoded = pd.get_dummies(df_train, columns=categorical, drop_first=True)
df_val_encoded = pd.get_dummies(df_val, columns=categorical, drop_first=True)
df_val_encoded = df_val_encoded.reindex(columns=df_train_encoded.columns, fill_value=0)

# %%
df_train_encoded = df_train_encoded.astype(int)
df_val_encoded = df_val_encoded.astype(int)

# %%
print(set(df_train_encoded.columns) - set(df_val_encoded.columns))
print(set(df_val_encoded.columns) - set(df_train_encoded.columns))
# Out:
# set()
# set()

# %%
print(df_train_encoded.index.equals(y_train_encoded.index))
# Out:
# True

# %%
print(df_train_encoded.shape[0])
print(y_train_encoded.shape[0])
# Out:
# 3295
# 3295

# %%
model.fit(df_train_encoded, y_train_encoded)
# Out:
# LogisticRegression(max_iter=1000, random_state=42, solver='liblinear')

# %%
y_pred = model.predict_proba(df_val_encoded)
y_pred
# Out:
# array([[0.21638998, 0.78361002],
#        [0.98967637, 0.01032363],
#        [0.97988782, 0.02011218],
#        ...,
#        [0.98861027, 0.01138973],
#        [0.99057612, 0.00942388],
#        [0.99002101, 0.00997899]])

# %%
y_pred_train = model.predict(df_train_encoded)
y_pred_val = model.predict(df_val_encoded)
print("Training Accuracy:", accuracy_score(y_train, y_pred_train))  # Or appropriate metric
# print("Validation Accuracy:", accuracy_score(y_val, y_pred_val))
# Out:
# Training Accuracy: 0.9180576631259484

# %%
y_val = df_val['y']
print("Validation Accuracy:", accuracy_score(y_val, y_pred_val))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'y'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[480], line 1
# ----> 1 y_val = df_val['y']
# ...

# %%
y_test = df_test['y']

# %%
y_pred_test = model.predict(df_test_encoded)
print("Testing Accuracy:",accuracy_score(y_test, y_pred_test))
# Out:
# Testing Accuracy: 0.9016990291262136

# %%
from sklearn.metrics import confusion_matrix , classification_report
y_pred_train = model.predict(df_train_encoded)
print(confusion_matrix(y_train_encoded, y_pred_train))
print(classification_report(y_train_encoded, y_pred_train))
# Out:
# [[2866   70]
#  [ 200  159]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96      2936
#            1       0.69      0.44      0.54       359
#
#     accuracy                           0.92      3295
#    macro avg       0.81      0.71      0.75      3295
# weighted avg       0.91      0.92      0.91      3295
